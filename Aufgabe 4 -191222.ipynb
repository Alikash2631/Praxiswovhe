# %%
import folium
m = folium.Map(location=[50.845152983170756, 6.899977551181547], zoom_start=10)

folium.Circle(
    location=[50.84898290814387, 6.917424201534123],
    radius=1
).add_to(m)

folium.Circle(
    location=[50.831724546351985, 6.837256561077162],
    radius=1
).add_to(m)

folium.Circle(
    location=[50.78525061903183, 6.864125509890007],
    radius=1
).add_to(m)

folium.Circle(
    location=[50.805260134145094, 6.941998465514515],
    radius=1
).add_to(m)

lls=[[50.84898290814387, 6.917424201534123],[50.831724546351985, 6.837256561077162],[50.78525061903183, 6.864125509890007],[52.04735138872293, 9.717419504369525],[50.805260134145094, 6.941998465514515]]

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
Rewe=[[50.84431951495816, 6.896575500699407], [50.84019268030618, 6.92097436724657], [50.830837170394595, 6.896357653676664],[50.82808519291479, 6.900061053063287]]

for i in Rewe:
    folium.Marker(i,popup=i,tooltip="Rewe",
                  icon=folium.Icon(color="green",
                                   Icon="cloud")
).add_to(m)
Norma=[[50.83453670998542, 6.899797644139709], [50.8377348373592, 6.919624533315022]]

for i in Norma:
    folium.Marker(i,popup=i,tooltip="Norma",
                  icon=folium.Icon(color="Red",
                                   Icon="cloud")
).add_to(m)  
    
Aldisüd=[[50.836864165229215, 6.92179681610782], [50.85884409705379, 6.899375254222588], [50.82885195436948, 6.899670274773708]]

for i in Aldisüd:
    folium.Marker(i,popup=i,tooltip="Aldi süd",
                  icon=folium.Icon(color="orange",
                                   Icon="cloud")
).add_to(m)        

Hit=[[50.82170998015744, 6.894403155852265]]

for i in Hit:
    folium.Marker(i,popup=i,tooltip="Hit",
                  icon=folium.Icon(color="purple",
                                   Icon="cloud")
).add_to(m)
    
Netto=[[50.83027336611352, 6.903916655046639], [50.82165774155488, 6.8917131013478565]]      
for i in Netto:
    folium.Marker(i,popup=i,tooltip="Netto",
                  icon=folium.Icon(color="darkgreen",
                                   Icon="cloud")
).add_to(m) 
    
Lidl=[[50.811136928880394, 6.898000503973814], [50.80833972157505, 6.815442546482065], [50.84975904515872, 6.782483561878947], [50.840654283122525, 6.909169658947182] ]      
for i in Lidl:
    folium.Marker(i,popup=i,tooltip="Lidl",
                  icon=folium.Icon(color="Pink",
                                   Icon="cloud")
).add_to(m) 
    
Kolinski=[[50.8163984409949, 6.904086335313441]]

for i in Kolinski:
    folium.Marker(i,popup=i,tooltip="Kolinski",
                  icon=folium.Icon(color="cadetblue",
                                   Icon="cloud")
).add_to(m)    
    
50.82976300914951, 6.916300157625319              
m
# Out:
# C:\Users\helli\AppData\Local\Temp\ipykernel_25832\888035108.py:13: UserWarning: color argument of Icon should be one of: {'beige', 'lightgreen', 'cadetblue', 'pink', 'green', 'darkgreen', 'blue', 'darkred', 'darkpurple', 'lightred', 'lightgray', 'red', 'orange', 'darkblue', 'purple', 'white', 'gray', 'black', 'lightblue'}.
#   icon=folium.Icon(color="Red",
# C:\Users\helli\AppData\Local\Temp\ipykernel_25832\888035108.py:43: UserWarning: color argument of Icon should be one of: {'beige', 'lightgreen', 'cadetblue', 'pink', 'green', 'darkgreen', 'blue', 'darkred', 'darkpurple', 'lightred', 'lightgray', 'red', 'orange', 'darkblue', 'purple', 'white', 'gray', 'black', 'lightblue'}.
#   icon=folium.Icon(color="Pink",
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
# ...

# %%
import geocoder
import geopy
import geographiclib 
import folium
import json
Brühl = f"https://raw.githubusercontent.com/isellsoap/BrühlGeoJSON/main/1_deutschland/4_niedrig.geo.json"

m = folium.Map(
    location=[50.84431951495816, 6.896575500699407],
    tiles="cartodbpositron",
    zoom_start=4,
)

folium.GeoJson(Brühl, name="geojson").add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Program Files\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
